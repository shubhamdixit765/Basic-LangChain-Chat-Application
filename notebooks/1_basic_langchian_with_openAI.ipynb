# %% [markdown]
# ### Langchain (Model - OpenAI)

# %% [markdown]
# ##### Load ENV Variables

# %%
# Import function to load variables from .env
from dotenv import load_dotenv

# Load environment variables into Python
load_dotenv()
# Out:
# True

# %%
import os

# %%
# Import LangChain's OpenAI chat model

from langchain_openai import ChatOpenAI

# Create a GPT-4o model instance

llm = ChatOpenAI(model="gpt-4o")

# Send a prompt to the model
response = llm.invoke("What is the capital of India?")

# Print only the model's text response
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[12], line 5
#       1 from langchain_openai import ChatOpenAI
#       2
#       3 llm = ChatOpenAI(model="gpt-4o")
#       4
# ----> 5 response = llm.invoke("What is the capital of India?")
#       6 print(response.content)
#
# File ~/Desktop/GenAI/env/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
# ...
